# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model='gemini-3-flash-preview')

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
initial_state = {'title': 'Ethanol blending in petrol in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Ethanol blending in petrol in India', 'outline': [{'type': 'text', 'text': 'This detailed blog outline is designed to cover the economic, environmental, and technical aspects of ethanol blending in India. It is structured to be SEO-friendly and engaging for a general audience.\n\n---\n\n# Blog Title: Fueling the Future: A Comprehensive Guide to Ethanol Blending in India\n\n## 1. Introduction\n*   **The Hook:** Start with the global shift towards green energy and India’s rising fuel demand.\n*   **Definition:** What is Ethanol Blending? (The process of mixing ethyl alcohol with petrol).\n*   **The Big Picture:** Briefly mention the Prime Minister’s roadmap for "E20" and why it’s a buzzword in Indian policy today.\n\n## 2. The Evolution of Ethanol Blending in India\n*   **The Timeline:** From E5 (5%) to the current achievement of E10 (10%).\n*   **The Shift in Targets:** Explain how India moved the deadline for 20% blending (E20) from 2030 to 2025-26.\n*   **Current Status:** Where does India stand today in terms of percentage and infrastructure?\n\n## 3. Why Ethanol? The Major Benefits\n*   **Economic Impact:**\n    *   Reducing the Oil Import Bill (Saving billions in foreign exchange).\n    *   Energy Security: Reducing dependence on volatile international crude markets.\n*   **Environmental Impact:**\n    *   Lower tailpipe emissions (Carbon Monoxide, Hydrocarbons).\n    *   Role in meeting India’s ‘Net Zero’ goals by 2070.\n*   **Agricultural Boost:**\n    *   Direct benefit to farmers (especially sugarcane and grain farmers).\n    *   Converting "Waste to Wealth" (using damaged grains and agricultural residue).\n\n## 4. Feedstock: How is Ethanol Produced in India?\n*   **1G Ethanol (First Generation):** Sugarcane juice, molasses, and food grains (damaged rice, corn).\n*   **2G Ethanol (Second Generation):** Non-edible agricultural waste like parali (paddy straw), corn cobs, and bamboo.\n*   **Diversification:** Why the government is moving beyond just sugarcane to ensure food security.\n\n## 5. Government Initiatives & Policy Support\n*   **National Policy on Biofuels (2018):** Key highlights and 2022 amendments.\n*   **Financial Incentives:** Interest subvention schemes for setting up distilleries.\n*   **Differential Pricing:** How the government sets different prices for ethanol produced from different sources to encourage production.\n*   **Tax Benefits:** GST reduction on ethanol intended for blending.\n\n## 6. Challenges and Roadblocks\n*   **Engine Compatibility:** Issues with older vehicles (corrosion of rubber and plastic parts).\n*   **Food vs. Fuel Debate:** The ethical concern of using land/crops for fuel instead of food.\n*   **Water Intensity:** The high water requirement for sugarcane cultivation.\n*   **Logistics & Storage:** Challenges in transporting ethanol and preventing water contamination (Ethanol is hygroscopic).\n\n## 7. Impact on the Consumer\n*   **Fuel Efficiency:** Does ethanol blending reduce mileage? (The energy density factor).\n*   **Vehicle Cost:** The rise of E20-compliant engines and Flex-Fuel Vehicles (FFVs).\n*   **Price at the Pump:** Will ethanol blending make petrol cheaper for the common man?\n\n## 8. The Future: Flex-Fuel Vehicles (FFVs)\n*   What are Flex-Fuel Vehicles? (Engines that can run on any blend from E20 to E100).\n*   The role of Indian OEMs (Maruti Suzuki, Toyota, TVS) in launching FFV prototypes.\n*   The potential for E100 (100% Ethanol) in the future.\n\n## 9. Conclusion\n*   **Summary:** Reiterate that ethanol blending is a "Win-Win-Win" for the Economy, Environment, and Farmers.\n*   **Final Thought:** The transition requires a balance between technological innovation and sustainable farming.\n*   **Call to Action (CTA):** Invite readers to share their thoughts on green fuel or subscribe for more energy updates.\n\n---\n\n### Suggested Keywords for SEO:\n*   *Ethanol Blending Program (EBP)*\n*   *E20 Fuel India*\n*   *Biofuels in India*\n*   *Flex Fuel Ve ...

# %%
print(final_state['outline'][0].get('text'))
# Out:
# This detailed blog outline is designed to cover the economic, environmental, and technical aspects of ethanol blending in India. It is structured to be SEO-friendly and engaging for a general audience.
#
# ---
#
# # Blog Title: Fueling the Future: A Comprehensive Guide to Ethanol Blending in India
#
# ## 1. Introduction
# *   **The Hook:** Start with the global shift towards green energy and India’s rising fuel demand.
# *   **Definition:** What is Ethanol Blending? (The process of mixing ethyl alcohol with petrol).
# *   **The Big Picture:** Briefly mention the Prime Minister’s roadmap for "E20" and why it’s a buzzword in Indian policy today.
#
# ## 2. The Evolution of Ethanol Blending in India
# *   **The Timeline:** From E5 (5%) to the current achievement of E10 (10%).
# *   **The Shift in Targets:** Explain how India moved the deadline for 20% blending (E20) from 2030 to 2025-26.
# *   **Current Status:** Where does India stand today in terms of percentage and infrastructure?
#
# ## 3. Why Ethanol? The Major Benefits
# *   **Economic Impact:**
#     *   Reducing the Oil Import Bill (Saving billions in foreign exchange).
#     *   Energy Security: Reducing dependence on volatile international crude markets.
# *   **Environmental Impact:**
#     *   Lower tailpipe emissions (Carbon Monoxide, Hydrocarbons).
#     *   Role in meeting India’s ‘Net Zero’ goals by 2070.
# *   **Agricultural Boost:**
#     *   Direct benefit to farmers (especially sugarcane and grain farmers).
#     *   Converting "Waste to Wealth" (using damaged grains and agricultural residue).
#
# ## 4. Feedstock: How is Ethanol Produced in India?
# *   **1G Ethanol (First Generation):** Sugarcane juice, molasses, and food grains (damaged rice, corn).
# *   **2G Ethanol (Second Generation):** Non-edible agricultural waste like parali (paddy straw), corn cobs, and bamboo.
# *   **Diversification:** Why the government is moving beyond just sugarcane to ensure food security.
#
# ## 5. Government Initiatives & Policy Support
# *   **National Policy on Biofuels (2018):** Key highlights and 2022 amendments.
# *   **Financial Incentives:** Interest subvention schemes for setting up distilleries.
# *   **Differential Pricing:** How the government sets different prices for ethanol produced from different sources to encourage production.
# *   **Tax Benefits:** GST reduction on ethanol intended for blending.
#
# ## 6. Challenges and Roadblocks
# *   **Engine Compatibility:** Issues with older vehicles (corrosion of rubber and plastic parts).
# *   **Food vs. Fuel Debate:** The ethical concern of using land/crops for fuel instead of food.
# *   **Water Intensity:** The high water requirement for sugarcane cultivation.
# *   **Logistics & Storage:** Challenges in transporting ethanol and preventing water contamination (Ethanol is hygroscopic).
#
# ## 7. Impact on the Consumer
# *   **Fuel Efficiency:** Does ethanol blending reduce mileage? (The energy density factor).
# *   **Vehicle Cost:** The rise of E20-compliant engines and Flex-Fuel Vehicles (FFVs).
# *   **Price at the Pump:** Will ethanol blending make petrol cheaper for the common man?
#
# ## 8. The Future: Flex-Fuel Vehicles (FFVs)
# *   What are Flex-Fuel Vehicles? (Engines that can run on any blend from E20 to E100).
# *   The role of Indian OEMs (Maruti Suzuki, Toyota, TVS) in launching FFV prototypes.
# *   The potential for E100 (100% Ethanol) in the future.
#
# ## 9. Conclusion
# *   **Summary:** Reiterate that ethanol blending is a "Win-Win-Win" for the Economy, Environment, and Farmers.
# *   **Final Thought:** The transition requires a balance between technological innovation and sustainable farming.
# *   **Call to Action (CTA):** Invite readers to share their thoughts on green fuel or subscribe for more energy updates.
#
# ---
#
# ### Suggested Keywords for SEO:
# *   *Ethanol Blending Program (EBP)*
# *   *E20 Fuel India*
# *   *Biofuels in India*
# *   *Flex Fuel Vehicles*
# *   *Indian Oil Import Bill*
# *   *Sugarcane to Ethanol*
#
# ### Visual Content Ideas for the Blog:
# *   **Infographic:** A timeline of India's blending targets (2014 to 2025).
# *   **Flowchart:** The production process from sugarcane/grain to the petrol pump.
# *   **Comparison Table:** E10 vs. E20 vs. E100 (Pros and Cons).

# %%
print(final_state['content'][0].get('text'))
# Out:
# # Fueling the Future: A Comprehensive Guide to Ethanol Blending in India
#
# As the world pivots toward a greener, more sustainable future, India is making bold strides to transform its energy landscape. With a rapidly growing economy and a thirst for energy that ranks third globally, the nation is looking inward to power its vehicles. Enter **Ethanol Blending**—a policy that is no longer just a buzzword in government corridors but a revolution brewing at your local petrol pump.
#
# In this guide, we dive deep into how India is mixing agriculture with automotive technology to create a cleaner, more self-reliant future.
#
# ---
#
# ## 1. Introduction: What is Ethanol Blending?
# At its simplest, ethanol blending is the process of mixing ethyl alcohol (ethanol) with petrol. Ethanol is a biofuel typically derived from the fermentation of sugar or starch-based crops.
#
# **Why the hype?** Prime Minister Narendra Modi’s roadmap for **"E20"** (20% ethanol blended with 80% petrol) has become a cornerstone of India’s energy policy. The goal is simple yet ambitious: reduce the carbon footprint of the transport sector while slashing the massive bill India pays to import crude oil.
#
# ---
#
# ## 2. The Evolution: From E5 to the E20 Sprint
# India’s journey with ethanol began slowly but has accelerated drastically in the last decade.
#
# *   **The Timeline:** We started with a modest E5 (5%) target. By 2022, India successfully achieved the **10% blending (E10)** milestone nationwide.
# *   **Shifting Gears:** Originally, the target to reach 20% blending (E20) was set for 2030. However, seeing the rapid progress, the government advanced the deadline to **2025-26**.
# *   **Current Status:** As of 2024, E20 fuel is already being rolled out at thousands of petrol pumps across India, supported by a massive expansion in distillery capacity.
#
# ---
#
# ## 3. Why Ethanol? The Triple-Win Strategy
# Ethanol blending is often called a "win-win-win" for the economy, the environment, and the farmers.
#
# ### Economic Impact
# *   **Slashing the Import Bill:** India imports over 85% of its crude oil. Higher ethanol blending could save the country over **₹30,000 crore annually** in foreign exchange.
# *   **Energy Security:** By producing fuel domestically, India reduces its vulnerability to volatile international oil prices and geopolitical tensions.
#
# ### Environmental Impact
# *   **Cleaner Air:** Ethanol is oxygen-rich, which leads to more complete combustion. This results in significantly lower tailpipe emissions of Carbon Monoxide (CO) and Hydrocarbons (HC).
# *   **Net Zero 2070:** It plays a vital role in India’s commitment to becoming a Net Zero emitter by 2070.
#
# ### Agricultural Boost
# *   **Empowering Farmers:** Ethanol provides an alternative market for sugarcane and grain farmers, ensuring they get paid even during a surplus harvest.
# *   **Waste to Wealth:** It allows the conversion of "C-heavy" molasses and damaged food grains into high-value fuel.
#
# ---
#
# ## 4. Feedstock: How is Ethanol Produced in India?
# India categorizes ethanol based on what it's made from:
#
# 1.  **1G Ethanol (First Generation):** Produced from edible sources like sugarcane juice, molasses, and food grains (damaged rice, broken corn). This currently forms the bulk of India's production.
# 2.  **2G Ethanol (Second Generation):** Produced from non-edible agricultural waste such as *parali* (paddy straw), corn cobs, and bamboo. This is the "frontier" technology that helps reduce stubble burning.
# 3.  **Diversification:** To ensure food security, the government is encouraging ethanol from maize and damaged grains rather than just relying on sugarcane.
#
# ---
#
# ## 5. Government Initiatives & Policy Support
# The surge in ethanol production isn't an accident; it’s the result of targeted policies:
# *   **National Policy on Biofuels (2018):** This provided the initial framework, which was amended in 2022 to fast-track the E20 target.
# *   **Financial Incentives:** The government offers **interest subvention schemes** for entrepreneurs looking to set up or expand ethanol distilleries.
# *   **Differential Pricing:** The government sets different prices for ethanol depending on the feedstock (e.g., more for juice-based, less for molasses-based) to ensure production remains profitable for mills.
# *   **GST Reduction:** The GST on ethanol meant for blending was slashed from 18% to **5%**.
#
# ---
#
# ## 6. Challenges and Roadblocks
# Despite the momentum, the road to E20 has some speed bumps:
# *   **Engine Compatibility:** Older vehicle engines (pre-2023) may face issues. Ethanol is corrosive to certain rubber and plastic components.
# *   **Food vs. Fuel:** There is an ethical debate regarding whether crops should be used to feed cars when they could feed people, especially during years of poor rainfall.
# *   **Water Intensity:** Sugarcane is a water-guzzling crop. Relying heavily on it for fuel could strain India's already depleted groundwater levels.
# *   **Logistics:** Ethanol is **hygroscopic** (it absorbs water from the air), making it difficult to store and transport through existing pipelines designed for pure petrol.
#
# ---
#
# ## 7. Impact on the Consumer
# What does this mean for you, the vehicle owner?
# *   **Fuel Efficiency:** Ethanol has lower energy density than petrol. This means you might see a **3-5% drop in mileage** when using E20 fuel.
# *   **Vehicle Cost:** New vehicles are now "E20 Compliant." However, the technology to make engines resistant to ethanol's corrosive properties may slightly increase the initial purchase price of the vehicle.
# *   **Price at the Pump:** While ethanol production is cheaper than importing oil, the price at the pump for the consumer is currently regulated to be similar to normal petrol to encourage adoption.
#
# ---
#
# ## 8. The Future: Flex-Fuel Vehicles (FFVs)
# The ultimate goal is the introduction of **Flex-Fuel Vehicles (FFVs)**.
# *   **What are they?** These vehicles have engines designed to run on any blend of petrol and ethanol—from **E20 all the way to E100 (100% ethanol)**.
# *   **Industry Movement:** Giants like **Maruti Suzuki, Toyota, and TVS** have already showcased FFV prototypes. Toyota recently unveiled the world's first BS6 (Stage II) electrified flex-fuel car in India.
# *   **The E100 Dream:** Imagine a future where your car runs entirely on locally produced, green alcohol!
#
# ---
#
# ## 9. Conclusion
# Ethanol blending is more than just a chemical mixture; it is a strategy for a "Smarter, Greener India." While challenges like water usage and engine compatibility remain, the benefits of energy independence and lower emissions are too significant to ignore. The transition requires a delicate balance between technological innovation and sustainable farming practices.
#
# As we move toward the 2025-26 deadline, India is proving that the fuel of the future isn't just under the ground—it’s growing in our fields.
#
# ---
# **What do you think about the shift to E20 fuel? Are you worried about your vehicle’s mileage, or are you excited about the greener footprint? Share your thoughts in the comments below!**
#
# *For more updates on green energy and the Indian economy, subscribe to our newsletter!*
#
# ---
# ### SEO Highlights:
# *   **Keywords:** Ethanol Blending Program (EBP), E20 Fuel India, Biofuels in India, Flex Fuel Vehicles, Indian Oil Import Bill, Sugarcane to Ethanol.
# *   **Search Intent:** Informational/Educational for Indian vehicle owners and policy enthusiasts.
